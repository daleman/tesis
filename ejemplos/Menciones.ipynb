# %%
# coding: utf-8

import tweepy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.options.display.max_columns = 50
pd.options.display.max_rows= 50
pd.options.display.width= 120

consumer_key ="cf6yoFiRnumb8YCgAc7i2890Z"
consumer_secret = "V4cP4UqqoYjiyxV8gsK9n91Bztg4qCowhFGLcjngTYBX6BfbmO"

auth = tweepy.OAuthHandler(consumer_key=consumer_key, consumer_secret=consumer_secret)


access_token = "3377301250-JkIbLxJp5oYnJHCJ3SVvBaOezBgTNGTSfyFGDiV"
access_token_secret = "TDaatB09DV6RjStolXxMayzAe2o836U280xwyI4Z173yj"
auth.set_access_token(access_token, access_token_secret)

# Creation of the actual interface, using authentication
api = tweepy.API(auth)

#Switching to application authentication
auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)

#Setting up new api wrapper, using authentication only
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
 
#Error handling
if (not api):
    print ("Problem Connecting to API")
else:
    print "Autenticado"
# Out:
# Autenticado

# %%
i= 0
total = 100000
all_tweets = []
for tweet in tweepy.Cursor(api.search,q='*',count=100,lang="es").items():
    i +=1
    if i % 1000 == 0:
        print i
    all_tweets.append(tweet)
    if i >= total:
        break
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# Rate limit reached. Sleeping for: 185
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# Rate limit reached. Sleeping for: 249
# 90000
# 91000
# 92000
# 93000
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-18-125b294dc05e> in <module>()
#       2 total = 100000
#       3 all_tweets = []
# ----> 4 for tweet in tweepy.Cursor(api.search,q='*',count=100,lang="es").items():
#       5     i +=1
#       6     if i % 1000 == 0:
#
# /usr/local/lib/python2.7/dist-packages/tweepy/cursor.pyc in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /usr/local/lib/python2.7/dist-packages/tweepy/cursor.pyc in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /usr/local/lib/python2.7/dist-packages/tweepy/binder.pyc in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /usr/local/lib/python2.7/dist-packages/tweepy/binder.pyc in execute(self)
#     187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
# --> 189                     raise TweepError('Failed to send request: %s' % e)
#     190                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#     191                 if rem_calls is not None:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)

# %%
places_dict = {}
loc = {}
geos = 0
nl = 0
for tweet in all_tweets:
    if tweet.user.location != None:
        location = tweet.user.location
        loc[location] = 1 if not loc.has_key(location) else loc[location] +1
    else:
        nl += 1
    if tweet.place != None:
        plc = tweet.place.name
        places_dict[plc] = 1 if not places_dict.has_key(plc) else places_dict[plc] + 1
    if tweet.user.geo_enabled:
        geos +=1


print "La cantidad de location == '' : " + str(loc['']) + ", el %" + str(100.0*(loc[''])/(len(all_tweets)))
print "La cantidad total de tweets: "  + str(len(all_tweets))
print "La cantidad de usarios con geolocalizacion " + str(geos) + ", el %" + str(100.0*(geos)/(len(all_tweets)))


canti = 20
for w in sorted(loc, key=loc.get, reverse=True)[:canti]:
    print w, loc[w]

# %%
plt.title("Histograma de lugares")
plt.xlabel("Lugares")
plt.ylabel("Frecuencia")

index = np.arange(len(loc.keys()))
bar_width = 0.35


cant = 15
valores = sorted(loc.values(),reverse=True)
claves = sorted(loc, key=loc.get,reverse=True)

opacity = 0.4
plt.xticks(index + bar_width, claves[:cant], size=6, rotation="vertical")
plt.bar(range(cant),valores[:cant],alpha=opacity,color='b',)
plt.tight_layout()
plt.show()

# %%
import json
cor = []
for tweet in all_tweets:
    if tweet.user.location == u'': 
        cor.append(tweet)


for c in cor:
    if hasattr(c,'retweeted_status'): # o tiene geolocalizacion
        print 'RETWEET ' + c.retweeted_status.user.location
    else:# o la persona de la que retwitteo tiene esa locacion
        print 'NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO ' + (c.place.name)
# Out:
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Adrogué, Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Coghlan, Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires,Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires  Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET buenos aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Mágica de Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires -Capital Federal
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina,Buenos Aires
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Argentina,Buenos Aires
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires | Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Mágica de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires. Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET VILLA CRESPO
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET BUENOS AIRES - ARGENTINA
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Baires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Baires
# RETWEET Buenos Aires, Argentina
# RETWEET  Buenos aires-Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina,Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Villa Devoto, Buenos Aires
# RETWEET Argentina,Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina,Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires City
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Madrid - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Madrid - Buenos Aires
# RETWEET Madrid - Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET BUENOS AIRES, ARGENTINA
# RETWEET Buenos Aires -
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires  Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires | Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires. Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Mágica de Buenos Aires
# RETWEET Ciudad Mágica de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires  Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Argentina, Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET buenos aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina.
# RETWEET Villa crespo
# RETWEET Buenos Aires, ARGENTINA
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Baires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET buenos aires, argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Cdad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires/Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET BUENOS AIRES - ARGENTINA
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Argentina,Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Baires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires.
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, ARGENTINA
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires(Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Santa María del Buen Ayre
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires(Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires,Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires. Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires - argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Zona Sur, Buenos Aires
# RETWEET Buenos Aires  Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires | Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET buenos Aires
# RETWEET Buenos Aires,  Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET buenos aires - argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Boedo, Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires-Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET  Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires-Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires,  Argentina
# RETWEET  Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires | Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires-Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET buenos aires, argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina - Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET argentina, buenos aires
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires, argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Ciudad Autónoma Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Mágica de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Argentina, Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Autónoma Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires ARGENTINA
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Autónoma Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET BUENOS AIRES - ARGENTINA
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Argentina - Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires, Argentina
# RETWEET BUENOS AIRES - ARGENTINA
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires -Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# RETWEET Argentina;Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET villa crespo
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Villa crespo
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos AIres
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Baires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos aires.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires -
# RETWEET Buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires,Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires, argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET La Boca, Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires. Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires. Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires. Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Magica de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires City
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Ciudad Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires,Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos aires Argentina
# RETWEET Buenos Aires | Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires. Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET buenos aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# NOOOOOOOOOOOOOOOOOOOOOOOOOOOOO GEO Ciudad Autónoma de Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Villa Del Parque, Buenos Aires
# RETWEET BAires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Barcelona - Buenos Aires
# RETWEET Buenos Aires
# RETWEET baires
# RETWEET Buenos Aires
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires

# %%
import json
cor = []
for tweet in all_tweets:
    if tweet.user.location == u'Córdoba, Argentina': 
        cor.append(tweet)


for c in cor:
    if c.place != None: # o tiene geolocalizacion
        print 'GEO ' + (c._json['place']['name'])
    else:# o la persona de la que retwitteo tiene esa locacion
         print 'RETWEET ' + c.retweeted_status.user.location
# Out:
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires.
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires, Argentina.
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires (Argentina)
# RETWEET Buenos Aires
# RETWEET Buenos Aires
# RETWEET Buenos Aires Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires.
# RETWEET Buenos Aires - Argentina
# RETWEET Buenos Aires, Argentina
# RETWEET Buenos Aires

# %%
user = api.get_user(screen_name = 'damianealeman')
print user.location
print user
# Out:
# User(follow_request_sent=None, has_extended_profile=True, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': True, u'profile_use_background_image': True, u'profile_text_color': u'333333', u'default_profile_image': False, u'id': 3377301250, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_location': None, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/621296170053332992/7RyoklBR_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 8, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'3377301250', u'profile_background_color': u'C0DEED', u'listed_count': 0, u'status': {u'contributors': None, u'truncated': False, u'text': u'A ver ahora asdqasdqasdq', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 799030529752526848, u'favorite_count': 0, u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': []}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'799030529752526848', u'favorited': False, u'geo': None, u'in_reply_to_user_id_str': None, u'lang': u'tr', u'created_at': u'Wed Nov 16 23:24:58 +0000 2016', u'in_reply_to_status_id_str': None, u'place': {u'full_name': u'Ciudad Aut\xf3noma de Buenos Aires, Argentina', u'url': u'https://api.twitter.com/1.1/geo/id/018f1cde6bad9747.json', u'country': u'Argentina', u'place_type': u'city', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[-58.5317922, -34.674453], [-58.353494, -34.674453], [-58.353494, -34.534177], [-58.5317922, -34.534177]]]}, u'contained_within': [], u'country_code': u'AR', u'attributes': {}, u'id': u'018f1cde6bad9747', u'name': u'Ciudad Aut\xf3noma de Buenos Aires'}}, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 11, u'description': u'', u'friends_count': 97, u'location': u'', u'profile_link_color': u'1DA1F2', u'profile_image_url': u'http://pbs.twimg.com/profile_images/621296170053332992/7RyoklBR_normal.jpg', u'following': None, u'geo_enabled': True, u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'name': u'Damian Aleman', u'lang': u'es', u'profile_background_tile': False, u'favourites_count': 1, u'screen_name': u'damianealeman', u'notifications': None, u'url': None, u'created_at': u'Wed Jul 15 12:30:21 +0000 2015', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'default_profile': True, u'is_translator': False}, time_zone=None, id=3377301250, description=u'', _api=<tweepy.api.API object at 0x7f68d04d0590>, verified=False, profile_location=None, profile_image_url_https=u'https://pbs.twimg.com/profile_images/621296170053332992/7RyoklBR_normal.jpg', profile_sidebar_fill_color=u'DDEEF6', is_translator=False, geo_enabled=True, entities={u'description': {u'urls': []}}, followers_count=8, protected=False, id_str=u'3377301250', default_profile_image=False, listed_count=0, status=Status(contributors=None, truncated=False, text=u'A ver ahora asdqasdqasdq', is_quote_status=False, in_reply_to_status_id=None, id=799030529752526848, favorite_count=0, _api=<tweepy.api.API object at 0x7f68d04d0590>, source=u'Twitter Web Client', _json={u'contributors': None, u'truncated': False, u'text': u'A ver ahora asdqasdqasdq', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 799030529752526848, u'favorite_count': 0, u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': []}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'799030529752526848',  ...
