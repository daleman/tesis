# %%
import json

with open('jujuy_followers.json', 'r') as f:
     data = json.load(f)
        
print data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-eb2380613914> in <module>()
#       2
#       3 with open('jujuy_followers.json', 'r') as f:
# ----> 4      data = json.load(f)
#       5
#       6 print data
#
# /usr/lib/python2.7/json/__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     289         parse_float=parse_float, parse_int=parse_int,
#     290         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 291         **kw)
#     292
#     293
#
# /usr/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
# coding: utf-8

import tweepy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.options.display.max_columns = 50
pd.options.display.max_rows= 50
pd.options.display.width= 120

consumer_key ="fshtLxpED9vXbZl5gVkaSowGr"
consumer_secret = "H2qEQC4wU2a1IkbKpNMlVbac1IV0vWlZMPmoyfyAVZCmZfUuZa"

auth = tweepy.OAuthHandler(consumer_key=consumer_key, consumer_secret=consumer_secret)


access_token = "3377301250-BAi7czgq59etPjYpZWFfJHOHIf048vaxsJ9G9Yo"
access_token_secret = "mpIeF0mEGjFTwUIUtd9nr20nu8O675zEFZlVPuTt12jcF"
auth.set_access_token(access_token, access_token_secret)

# Creation of the actual interface, using authentication
#api = tweepy.API(auth)

print "Autenticado"
#print api.rate_limit_status()
#Switching to application authentication
auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)

#Setting up new api wrapper, using authentication only
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
 
#Error handling
if (not api):
    print ("Problem Connecting to API")
# Out:
# Autenticado

# %%
for user in tweepy.Cursor(api.followers, screen_name="damianealeman").items():
    print user.screen_name, user.location
# Out:
# SusiClima Ciudad Autónoma de Buenos Aire
# MHolocaustoBsAs Montevideo 919, CABA
# WinnikBettina
# juventudhacoaj
# FraguaCultural
# Laoncediez Buenos Aires - Argentina
# ahutnik8 Buenos Aires, Argentina
# julytomm
# kobra14

# %%
import csv
coords = {}
with open('coordenadas2.csv', 'rb') as f:
    reader = csv.reader(f)
    for row in reader:
        if row[1] in coords:
            coords[row[1]].append(row[2])
        else:
            coords[row[1]] = [row[2]]
        #print row
        
for prov in coords.keys():
    print 'provincias' + "['" +prov + "']['coords'] = " + str(coords[prov])
# Out:
# provincias['jujuy']['coords'] = ['-22.722674,-65.696983', '-24.185786,-65.299477', '-24.389346,-65.261621', '-23.203963,-65.348609', '-23.815332,-64.792826', '-24.258413,-65.208491', '-22.618153,-66.52239', '-33.4180372    ,    -63.29700150000002', '-24.231028,-64.868306', '-24.310992,-64.661094', '-21.946447,-66.051476', '-23.416667,-66.483333', '-23.57687,-65.393374', '-23.857719,-65.467586', '-23.476351,-64.946702', '-22.104403,-65.596771']
# provincias['catamarca']['coords'] = ['-28.159277,-65.792616', '-28.812043,-65.50083', '-27.582719,-66.314891', '-26.059566,-67.406469', '-27.650239,-67.025948', '-28.725886,-65.978039', '-28.469581,-65.77954410000001', '-28.31075,-65.363842', '-28.285005,-65.737175', '-29.278189,-65.058385', '-28.153814,-65.659055', '-28.18268,-66.233841', '-26.703544,-66.045912', '-28.105639,-65.318505', '-28.062662,-67.566074', '-28.449206,-65.726124']
#coord = '-51.6352821,-69.2474353'
coords = ['-51.6230485,-69.21682909999998','-50.337969,-72.26479810000001','-46.4425647,-67.51715330000002']

cant_tweets = 50
ids = {}
loc = {}
all_tweets = []

words = provincias['santacruz']['words']

for coord in coords:
    i = 0
    print coord
    for tweet in tweepy.Cursor(api.search, count=100,lang="es",geocode=(coord + ',10mi')).items():
        #print(tweet.id)
        i += 1
        if i % 100 == 0:
            print i, len(ids)
        if tweet.user.location!="":  
            location=unicodedata.normalize('NFKD',tweet.user.location).encode('ASCII', 'ignore').lower().replace('-',' ').replace(';',' ').replace(',',' ').replace('|',' ').replace('?',' ').replace('¿',' ').replace("\ ",' ').replace('/',' ')
            all_tweets.append(tweet)
            #print tweet.created_at
            matches=[x for x in location.split(' ') if x in words]
            if len(matches)>0 and tweet.user.id not in ids:
                ids[tweet.user.id] = 1
                location = tweet.user.location
                loc[location] = 1 if not loc.has_key(location) else loc[location] +1
            #print tweet.user.location
        if i >= cant_tweets:
            print 'salgo'
            break
# Out:
# -51.6230485,-69.21682909999998
# salgo
# -50.337969,-72.26479810000001
# salgo
# -46.4425647,-67.51715330000002
# salgo

# %%
import json
with open("./prov_json/entrerios_users.json", "r") as ins:
    array = []
    for line in ins:
        d = json.loads(line)
        print d["location"]
        array.append(d)
# Out:
# capital federal
# Chajarí (Entre Ríos )
# Parana. Entre Rios.
# Concordia
# Entre Ríos, Argentina
# Entre Ríos, Argentina
# Villaguay, Argentina
# Villaguay, Argentina
# Entre Ríos, Argentina
# Paraná, Argentina
# Capital Federal Argentina
# Capital Federal
# Entre Ríos, Argentina
# Entre Ríos, Argentina
# Paraná
# Santa Anita, Entre Rios
# Villaguay, Argentina
# Nogoya
# Entre Ríos, Argentina
# Federal Entre Rios
# Entre Ríos, Argentina
# Entre Ríos, Argentina
# Entre Ríos, Argentina
# Entre Ríos, Argentina
# Gualeguaychú, Entre Rios
# Argentina. Entre Ríos
#  Villa Paranacito ,Entre Rios
# Nogoya,Entre Rios
# Entre Ríos, Argentina
# Paraná-Entre Rios
# Entre Ríos, Argentina
# Concordia
# Gualeguaychú, Argentina
# Victoria, Entre Ríos
# , Argentina,Entre Rios,Federal
# villa concepcion del   tío
# Capital Federal, Argentina
# Concepcion, Pcia de Tuc
# Gualeguaychú, Argentina
# parana entre rios
# Paraná, Argentina
# Federal, Entre Rios, Argentina
# Entre Ríos, Argentina
# ...

# %%
import unicodedata
#coord = '-51.6352821,-69.2474353'
#coords = ['-51.6230485,-69.21682909999998','-50.337969,-72.26479810000001','-46.4425647,-67.51715330000002']
coords = ['-48.951366,-70.136719']
cant_tweets = 15000
ids = {}
loc = {}
all_tweets = []

words = provincias['santacruz']['words']

for coord in coords:
    i = 0
    for tweet in tweepy.Cursor(api.search, count=100,lang="es",geocode=(coord + ',200mi')).items():
        #print(tweet.id)
        i += 1
        if i % 100 == 0:
            print i, len(ids)
        if tweet.user.location!="":  
            location=unicodedata.normalize('NFKD',tweet.user.location).encode('ASCII', 'ignore').lower().replace('-',' ').replace(';',' ').replace(',',' ').replace('|',' ').replace('?',' ').replace('¿',' ').replace("\ ",' ').replace('/',' ')
            all_tweets.append(tweet)
            #print tweet.created_at
            matches=[x for x in location.split(' ') if x in words]
            if len(matches)>0 and tweet.user.id not in ids:
                ids[tweet.user.id] = 1
                location = tweet.user.location
                loc[location] = 1 if not loc.has_key(location) else loc[location] +1
            #print tweet.user.location
        if i >= cant_tweets:
            break
# Out:
# 100 53
# 200 91
# 300 134
# 400 171
# 500 196
# 600 220
# 700 229
# 800 259
# 900 276
# 1000 296
# 1100 319
# 1200 338
# 1300 354
# 1400 372
# 1500 381
# 1600 397
# 1700 423
# 1800 448
# 1900 478
# 2000 505
# 2100 531
# 2200 551
# 2300 577
# 2400 608
# 2500 630
# 2600 641
# 2700 664
# 2800 677
# 2900 692
# 3000 704
# 3100 726
# 3200 748
# 3300 778
# 3400 790
# 3500 805
# 3600 820
# 3700 832
# 3800 854
# 3900 870
# 4000 888
# 4100 910
# 4200 921
# 4300 939
# 4400 956
# 4500 966
# 4600 991
# 4700 1008
# 4800 1027
# 4900 1039
# 5000 1058
# 5100 1069
# 5200 1076
# 5300 1083
# 5400 1094
# 5500 1099
# 5600 1108
# 5700 1117
# 5800 1130
# 5900 1136
# 6000 1146
# 6100 1156
# 6200 1163
# 6300 1168
# 6400 1174
# 6500 1184
# 6600 1193
# 6700 1202
# 6800 1216
# 6900 1220
# 7000 1225
# 7100 1237
# 7200 1243
# 7300 1251
# 7400 1260
# 7500 1269
# 7600 1281
# 7700 1288
# 7800 1298
# 7900 1310
# 8000 1318
# 8100 1328
# 8200 1335
# 8300 1345
# 8400 1350
# 8500 1358
# 8600 1369
# 8700 1380
# 8800 1388
# ...

# %%
plt.title("Histograma de lugares")
plt.xlabel("Lugares")
plt.ylabel("Frecuencia")

index = np.arange(len(loc.keys()))
bar_width = 0.35


cant = 15
valores = sorted(loc.values(),reverse=True)
claves = sorted(loc, key=loc.get,reverse=True)

opacity = 0.4
plt.xticks(index + bar_width, claves[:cant], size=6, rotation="vertical")
plt.bar(range(cant),valores[:cant],alpha=opacity,color='b',)
plt.tight_layout()
plt.show()

# %%
import unicodedata
#coord = '-51.6352821,-69.2474353'
#coords = ['-51.6230485,-69.21682909999998','-50.337969,-72.26479810000001','-46.4425647,-67.51715330000002']
coords = ['-31.5741,-59.281']
cant_tweets = 15000
ids = {}
loc = {}
all_tweets = []

words = provincias['entrerios']['words']
print words
for coord in coords:
    i = 0
    for tweet in tweepy.Cursor(api.search, count=100,lang="es",geocode=(coord + ',150mi')).items():
        #print(tweet.id)
        i += 1
        if i % 100 == 0:
            print i, len(ids)
        if tweet.user.location!="":  
            location=unicodedata.normalize('NFKD',tweet.user.location).encode('ASCII', 'ignore').lower().replace('-',' ').replace(';',' ').replace(',',' ').replace('|',' ').replace('?',' ').replace('¿',' ').replace("\ ",' ').replace('/',' ')
            all_tweets.append(tweet)
            #print tweet.created_at
            matches=[x for x in location.split(' ') if x in words]
            if len(matches)>0 and tweet.user.id not in ids:
                ids[tweet.user.id] = 1
                location = tweet.user.location
                loc[location] = 1 if not loc.has_key(location) else loc[location] +1
            #print tweet.user.location
        if i >= cant_tweets:
            break
# Out:
# ['entre', 'rios', 'er', 'parana', 'federal', 'paz', 'colon', 'gualeguay', 'gualeguaychu', 'feliciano', 'nogoya', 'villaguay', 'concepcion', 'diamante', 'tala', 'gustuvo', 'gualeguay', 'victoria', 'elisa', 'cimarron', 'aranqueren', 'crespo', 'aranguren', 'chajari', 'elena', 'ibicuy', 'concordia', 'feliciano', 'diamante', 'tala']
# 100 15
# 200 38
# 300 57
# 400 68
# 500 85
# 600 104
# 700 120
# 800 131
# 900 140
# 1000 158
# 1100 172
# 1200 192
# 1300 204
# 1400 220
# 1500 230
# 1600 241
# 1700 252
# 1800 264
# 1900 278
# 2000 289
# 2100 299
# 2200 308
# 2300 325
# 2400 334
# 2500 350
# 2600 369
# 2700 377
# 2800 387
# 2900 403
# 3000 416
# 3100 432
# 3200 444
# 3300 460
# 3400 473
# 3500 488
# 3600 499
# 3700 512
# 3800 524
# 3900 532
# 4000 545
# 4100 555
# 4200 569
# 4300 573
# 4400 582
# 4500 596
# 4600 605
# 4700 617
# 4800 623
# 4900 634
# 5000 643
# 5100 656
# 5200 665
# 5300 675
# 5400 683
# 5500 689
# 5600 704
# 5700 717
# 5800 731
# 5900 740
# 6000 745
# 6100 755
# 6200 769
# ...

# %%
def plot(canti):
    plt.title("Histograma de lugares")
    plt.xlabel("Lugares")
    plt.ylabel("Frecuencia")

    index = np.arange(len(loc.keys()))
    bar_width = 0.35


    cant = canti
    valores = sorted(loc.values(),reverse=True)
    claves = sorted(loc, key=loc.get,reverse=True)

    opacity = 0.4
    plt.xticks(index + bar_width, claves[:cant], size=6, rotation="vertical")
    plt.bar(range(cant),valores[:cant],alpha=opacity,color='b',)
    plt.tight_layout()
    plt.show()

plot(20)

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
cant_tweets = 100
ids = {}
loc = {}
all_tweets = []
for coord in coordenadas.keys():
    i= 0
    tweets.append(all_tweets)
    all_tweets = []
    
    print coord
    #for tweet in tweepy.Cursor(api.search, count=100,lang="es",geocode="-34.5916734896,-58.3918617027,3mi").items():
    for tweet in tweepy.Cursor(api.search, count=100,lang="es",geocode=(coordenadas[coord] + ',10mi')).items():
        #print(tweet.id)
        i += 1
        if i % 100 == 0:
            print i, len(ids)
        all_tweets.append(tweet)
        print tweet.created_at
        if tweet.user.id not in ids:
            ids[tweet.user.id] = 1
            location = tweet.user.location
            loc[location] = 1 if not loc.has_key(location) else loc[location] +1
        #print tweet.user.location
        if len(all_tweets) >= cant_tweets:
            break

# %%
provincias={
# %%
import sys
import json
import os
import unicodedata
import math

id = []
#for prov in provincias.keys():
q= "Argentina"
places = api.geo_search(query=q,granulartity='country')
for place in places:
    print "id de " + str(q) + ": " +place.id + ' ' +  place.place_type, place.full_name

# %%
print "Autenticado"
#print api.rate_limit_status()
#Switching to application authentication
auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)

#Setting up new api wrapper, using authentication only
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
 
#Error handling
if (not api):
    print ("Problem Connecting to API")
i= 0
cant_tweets = 100000
all_tweets = []

try:
    for tweet in tweepy.Cursor(api.search,q="place:%s" % place_id,count = 100).items():
        #print(tweet.id)
        i += 1
        if i % 1000 == 0:
            print i
        all_tweets.append(tweet)
        if len(all_tweets) >= cant_tweets:
            break
except Exception, e:
         pass

# %%
f_tweets_jujuy = open('jujuy_tweets.json', 'a')
f_users_jujuy = open('jujuy_users.json', 'a')
f_tweets_catamarca = open('catamarca_tweets.json', 'a')
f_users_catamarca = open('catamarca_users.json', 'a')
f_tweets_sanjuan = open('sanjuan_tweets.json', 'a')
f_users_sanjuan = open('sanjuan_users.json', 'a')
f_tweets_salta = open('salta_tweets.json', 'a')
f_users_salta = open('salta_users.json', 'a')
f_tweets_rionegro = open('rionegro_tweets.json', 'a')
f_users_rionegro = open('rionegro_users.json', 'a')
f_tweets_lapampa = open('lapampa_tweets.json', 'a')
f_users_lapampa = open('lapampa_users.json', 'a')
f_tweets_chaco = open('chaco_tweets.json', 'a')
f_users_chaco = open('chaco_users.json', 'a')
f_tweets_mendoza = open('mendoza_tweets.json', 'a')
f_users_mendoza = open('mendoza_users.json', 'a')
f_tweets_buenosaires = open('buenosaires_tweets.json', 'a')
f_users_buenosaires = open('buenosaires_users.json', 'a')
f_tweets_entrerios = open('entrerios_tweets.json', 'a')
f_users_entrerios = open('entrerios_users.json', 'a')
f_tweets_chubut = open('chubut_tweets.json', 'a')
f_users_chubut = open('chubut_users.json', 'a')
f_tweets_santacruz = open('santacruz_tweets.json', 'a')
f_users_santacruz = open('santacruz_users.json', 'a')
f_tweets_neuquen = open('neuquen_tweets.json', 'a')
f_users_neuquen = open('neuquen_users.json', 'a')
f_tweets_misiones = open('misiones_tweets.json', 'a')
f_users_misiones = open('misiones_users.json', 'a')
f_tweets_corrientes = open('corrientes_tweets.json', 'a')
f_users_corrientes = open('corrientes_users.json', 'a')
f_tweets_formosa = open('formosa_tweets.json', 'a')
f_users_formosa = open('formosa_users.json', 'a')
f_tweets_santafe = open('santafe_tweets.json', 'a')
f_users_santafe = open('santafe_users.json', 'a')
f_tweets_santiago = open('santiago_tweets.json', 'a')
f_users_santiago = open('santiago_users.json', 'a')
f_tweets_cordoba = open('cordoba_tweets.json', 'a')
f_users_cordoba = open('cordoba_users.json', 'a')
f_tweets_larioja = open('larioja_tweets.json', 'a')
f_users_larioja = open('larioja_users.json', 'a')
f_tweets_tierradelfuego = open('tierradelfuego_tweets.json', 'a')
f_users_tierradelfuego = open('tierradelfuego_users.json', 'a')
f_tweets_tucuman = open('tucuman_tweets.json', 'a')
f_users_tucuman = open('tucuman_users.json', 'a')
f_tweets_sanluis = open('sanluis_tweets.json', 'a')
f_users_sanluis = open('sanluis_users.json', 'a')

files_prov = {
'jujuy': {'users': f_users_jujuy, 'tweets': f_tweets_jujuy},
'catamarca': {'users': f_users_catamarca, 'tweets': f_tweets_catamarca},
'sanjuan': {'users': f_users_sanjuan, 'tweets': f_tweets_sanjuan},
'salta': {'users': f_users_salta, 'tweets': f_tweets_salta},
'rionegro': {'users': f_users_rionegro, 'tweets': f_tweets_rionegro},
'lapampa': {'users': f_users_lapampa, 'tweets': f_tweets_lapampa},
'chaco': {'users': f_users_chaco, 'tweets': f_tweets_chaco},
'mendoza': {'users': f_users_mendoza, 'tweets': f_tweets_mendoza},
'buenosaires': {'users': f_users_buenosaires, 'tweets': f_tweets_buenosaires},
'entrerios': {'users': f_users_entrerios, 'tweets': f_tweets_entrerios},
'chubut': {'users': f_users_chubut, 'tweets': f_tweets_chubut},
'santacruz': {'users': f_users_santacruz, 'tweets': f_tweets_santacruz},
'neuquen': {'users': f_users_neuquen, 'tweets': f_tweets_neuquen},
'misiones': {'users': f_users_misiones, 'tweets': f_tweets_misiones},
'corrientes': {'users': f_users_corrientes, 'tweets': f_tweets_corrientes},
'formosa': {'users': f_users_formosa, 'tweets': f_tweets_formosa},
'santafe': {'users': f_users_santafe, 'tweets': f_tweets_santafe},
'santiago': {'users': f_users_santiago, 'tweets': f_tweets_santiago},
'cordoba': {'users': f_users_cordoba, 'tweets': f_tweets_cordoba},
'larioja': {'users': f_users_larioja, 'tweets': f_tweets_larioja},
'tierradelfuego': {'users': f_users_tierradelfuego, 'tweets': f_tweets_tierradelfuego},
'tucuman': {'users': f_users_tucuman, 'tweets': f_tweets_tucuman},
'sanluis': {'users': f_users_sanluis, 'tweets': f_tweets_sanluis}
}

        
        
ids= {}

    
for data in all_tweets:
    if data.user.location!="":  
        location=unicodedata.normalize('NFKD',data.user.location).encode('ASCII', 'ignore').lower().replace('-',' ').replace(';',' ').replace(',',' ').replace('|',' ').replace('?',' ').replace('¿',' ').replace("\ ",' ').replace('/',' ')
        seg = 0
        for prov in provincias.keys():
            
            words = provincias[prov]['words']
            matches=[x for x in location.split(' ') if x in words]
            if len(matches)>0 and data.user.id not in ids:
                files_prov[prov]['users'].write(json.dumps(data._json['user']))
                files_prov[prov]['users'].write("\n")
                files_prov[prov]['tweets'].write(json.dumps(data._json))
                files_prov[prov]['tweets'].write("\n")
                ids[data.user.id] = 1
                seg +=1
                if seg> 1:
                    print "lo agrego " + seg + "veces"


for f_prov in files_prov.keys():
    files_prov[f_prov]['users'].close()
    files_prov[f_prov]['tweets'].close()
                    
len(all_tweets)

# %%
print len(ids.keys())

# %%
for prov in provincias.keys():
    print "'" + prov + "': {'users': f_users_" + prov+", 'tweets': f_tweets_" + prov+"},"
